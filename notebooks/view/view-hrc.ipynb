# %% [markdown]
# # View HRC data

# %%
hrc_data = '/home/xiuhao/work/Dataset/HRCdata/Train'
from pathlib import Path as P
from meterviewer.views.quick import fast_preview
def more_faster(dataset):
    x, y = fast_preview(dataset)

# %%
fast_preview(P(hrc_data))
# Out:
# Data written to '/home/xiuhao/work/Dataset/HRCdata/Train/details.gen.toml' successfully.
# (array([[[[140, 146, 141],
#           [140, 146, 141],
#           [140, 147, 141],
#           ...,
#           [153, 137, 135],
#           [152, 137, 134],
#           [152, 137, 134]],
#
#          [[141, 147, 142],
#           [141, 147, 142],
#           [141, 147, 142],
#           ...,
#           [154, 139, 137],
#           [154, 139, 137],
#           [154, 139, 137]],
#
#          [[143, 149, 144],
#           [143, 149, 144],
#           [143, 149, 144],
#           ...,
#           [156, 141, 139],
#           [155, 141, 139],
#           [155, 141, 139]],
#
#          ...,
#
#          [[ 56,  58,  58],
#           [ 56,  58,  58],
#           [ 56,  58,  58],
#           ...,
#           [ 31,  32,  34],
#           [ 31,  32,  34],
#           [ 31,  32,  34]],
#
#          [[ 56,  58,  58],
#           [ 56,  58,  58],
#           [ 56,  59,  58],
#           ...,
#           [ 31,  32,  33],
#           [ 31,  32,  33],
#           [ 31,  32,  33]],
#
#          [[ 57,  59,  58],
#           [ 57,  59,  58],
#           [ 57,  59,  58],
#           ...,
#           [ 31,  32,  33],
#           [ 31,  32,  33],
#           [ 31,  32,  33]]],
#
#
#         [[[121, 117, 113],
#           [121, 117, 113],
#           [122, 118, 113],
#           ...,
#           [ 86,  69,  61],
#           [ 86,  69,  61],
#           [ 86,  69,  61]],
#
#          [[116, 110, 105],
#           [117, 111, 106],
#           [118, 112, 107],
#           ...,
#           [ 88,  71,  62],
#           [ 88,  71,  62],
#           [ 88,  71,  62]],
#
#          [[129, 125, 120],
#           [129, 125, 120],
#           [130, 126, 121],
#           ...,
#           [ 89,  72,  63],
#           [ 89,  72,  63],
#           [ 89,  72,  63]],
#
#          ...,
#
#          [[ 43,  43,  43],
#           [ 43,  43,  43],
#           [ 43,  43,  43],
#           ...,
#           [ 29,  26,  25],
#           [ 29,  26,  25],
#           [ 29,  26,  25]],
#
#          [[ 43,  43,  43],
#           [ 43,  43,  43],
#           [ 43,  43,  43],
#           ...,
#           [ 29,  26,  25],
#           [ 29,  26,  25],
#           [ 29,  26,  25]],
#
#          [[ 44,  44,  44],
#           [ 44,  44,  44],
#           [ 44,  44,  44],
#           ...,
#           [ 29,  26,  25],
#           [ 29,  26,  25],
#           [ 29,  26,  25]]],
#
#
#         [[[ 64,  64,  64],
#           [ 64,  64,  64],
#           [ 65,  65,  65],
#           ...,
#           [ 83,  73,  69],
#           [ 83,  73,  68],
#           [ 83,  73,  68]],
#
#          [[ 62,  62,  62],
#           [ 62,  62,  62],
#           [ 63,  63,  63],
#           ...,
#           [ 83,  73,  68],
#           [ 82,  73,  68],
#           [ 82,  73,  68]],
#
#          [[ 60,  60,  60],
#           [ 60,  60,  60],
#           [ 60,  60,  60],
#           ...,
#           [ 84,  74,  70],
#           [ 83,  73,  69],
#           [ 83,  73,  69]],
#
#          ...,
#
#          [[ 67,  74,  77],
#           [ 67,  74,  77],
#           [ 67,  74,  77],
#           ...,
#           [ 75,  70,  89],
#           [ 71,  66,  85],
#           [ 70,  65,  83]],
#
#          [[ 67,  76,  80],
#           [ 67,  76,  80],
#           [ 67,  76,  80],
#           ...,
#           [ 68,  64,  78],
#           [ 67,  63,  75],
#           [ 66,  63,  74]],
#
#          [[ 68,  77,  81],
#           [ 68,  77,  81],
#           [ 68,  77,  81],
#           ...,
#           [ 65,  62,  73],
#           [ 64,  62,  70],
#           [ 64,  62,  69]]],
#
#
#         ...,
#
#
#         [[[124, 124, 112],
#           [124, 124, 112],
#           [123, 123, 111],
#           ...,
#           [154, 135, 132],
#           [152, 133, 130],
#           [151, 132, 129]],
#
#          [[127, 127, 115],
#           [127, 127, 115],
#           [127, 127, 115],
#           ...,
#           [155, 136, 133],
#           [153, 134, 131],
#           [152, 133, 130]],
#
#          [[127, 131, 119],
#           [128, 131, 120],
#           [129, 132, 121],
#           ...,
#           [154, 139, 137],
#           [153, 138, 136],
#           [152, 137, 135]],
#
#          ...,
#
#          [[ 50,  51,  49],
#           [ 50,  51,  49],
#           [ 50,  51,  49],
#           ...,
#           [ 25,  24,  26],
#           [ 25,  25,  27],
#           [ 25,  26,  27]],
#
#          [[ 50,  51,  49],
#           [ 50,  51,  49],
#           [ 50,  51,  49],
#           ...,
#           [ 43,  43,  45],
#           [ 41,  42,  43],
#           [ 40,  41,  42]],
#
#          [[ 50,  51,  49],
#           [ 50,  51,  49],
#           [ 51,  52,  49],
#           ...,
#           [ 53,  52,  54],
#           [ 52,  53,  54],
#           [ 52,  53,  54]]],
#
#
#         [[[102, 104, 102],
#           [102, 104, 102],
#           [101, 104, 101],
#           ...,
#           [122, 102,  95],
#           [122, 102,  95],
#           [122, 102,  95]],
#
#          [[ 96,  99,  98],
#           [ 95,  99,  97],
#           [ 94,  98,  96],
#           ...,
#           [117,  99,  92],
#           [117,  99,  92],
#           [117,  99,  92]],
#
#          [[ 87,  92,  91],
#           [ 86,  91,  90],
#           [ 85,  90,  89],
#           ...,
#           [102,  89,  85],
#           [103,  90,  85],
#           [103,  90,  85]],
#
#          ...,
#
#          [[ 22,  22,  20],
#           [ 22,  22,  20],
#           [ 22,  22,  21],
#           ...,
#           [ 13,  14,  16],
#           [ 13,  14,  15],
#           [ 13,  14,  15]],
#
#          [[ 24,  24,  21],
#           [ 24,  24,  21],
#           [ 24,  24,  21],
#           ...,
#           [ 14,  15,  15],
#           [ 14,  14,  15],
#           [ 14,  14,  15]],
#
#          [[ 24,  24,  22],
#           [ 24,  24,  22],
#           [ 25,  24,  22],
#           ...,
#           [ 15,  15,  15],
#           [ 15,  15,  15],
#           [ 15,  15,  15]]],
#
#
#         [[[ 92,  86,  87],
#           [ 96,  90,  91],
#           [102,  96,  97],
#           ...,
#           [159, 164, 163],
#           [163, 168, 167],
#           [164, 169, 168]],
#
#          [[ 89,  83,  84],
#           [ 93,  87,  88],
#           [100,  94,  95],
#           ...,
#           [155, 159, 158],
#           [158, 163, 162],
#           [159, 164, 163]],
#
#          [[ 85,  79,  80],
#           [ 89,  83,  84],
#           [ 96,  90,  91],
#           ...,
#           [142, 145, 144],
#           [143, 146, 145],
#           [143, 146, 145]],
#
#          ...,
#
#          [[ 28,  26,  25],
#           [ 28,  26,  25],
#           [ 28,  25,  24],
#           ...,
#           [ 16,  16,  16],
#           [ 16,  16,  16],
#           [ 16,  16,  16]],
#
#          [[ 30,  27,  27],
#           [ 30,  27,  27],
#           [ 29,  27,  26],
#           ...,
#           [ 16,  16,  16],
#           [ 16,  16,  16],
#           [ 16,  16,  16]],
#
#          [[ 31,  29,  29],
#           [ 31,  29,  28],
#           [ 30,  28,  27],
#           ...,
#           [ 16,  16,  16],
#           [ 16,  16,  16],
#           [ 16,  16,  16]]]], dtype=uint8),
#  array([['000828'],
#         ['000917'],
#         ['001857'],
#         ...,
#         ['003030'],
#         ['000825'],
#         ['012653']], dtype='<U6'))
