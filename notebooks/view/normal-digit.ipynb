# %%
current_dataset = r"D:\Store\MeterData\lens_6\XL\merge_np\Digit\Train"

# %%
from meterviewer import dataset, files, types as T
from meterviewer.views import current
from pathlib import Path as P

# %%
p = P(current_dataset)
current.view_merge_np(current_dataset, view_dataset=dataset.view_dataset_in_rows)
current.write_details(current_dataset)
# Out:
# Data written to 'D:\Store\MeterData\lens_6\XL\merge_np\Digit\Train\details.toml' successfully.
