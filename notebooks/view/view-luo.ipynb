# %% [markdown]
# # view luo dataset

# %%
from pathlib import Path as P
from meterviewer.views.quick import fast_preview
def more_faster(dataset):
    x, y = fast_preview(dataset)

# %%
last_data = '/home/xiuhao/work/Dataset/luojianxun/GraduationDesign/pytorch/data/last_data'
whole_img = '/home/xiuhao/work/Dataset/luojianxun/whole_img/numpy'
new_meter = '/home/xiuhao/work/Dataset/luojianxun/GraduationDesign/pytorch/data/new_meter'

for data_path in (last_data, whole_img, new_meter):
    dataset = P(data_path)
    fast_preview(dataset)
# Out:
# Data written to '/home/xiuhao/work/Dataset/luojianxun/GraduationDesign/pytorch/data/last_data/details.gen.toml' successfully.
# Data written to '/home/xiuhao/work/Dataset/luojianxun/whole_img/numpy/details.gen.toml' successfully.
# Data written to '/home/xiuhao/work/Dataset/luojianxun/GraduationDesign/pytorch/data/new_meter/details.gen.toml' successfully.
