# %%
from pathlib import Path as P
from meterviewer.views.quick import fast_preview

# %%
dataset = P('/Users/xiuhao/Work/Dataset/no_tilt_merge/block_Train')

# %%
fast_preview(dataset)
# Out:
# Data written to '/Users/xiuhao/Work/Dataset/no_tilt_merge/block_Train/details.toml' successfully.
# PosixPath('/Users/xiuhao/Work/Dataset/no_tilt_merge/block_Train')
