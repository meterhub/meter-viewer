# %% [markdown]
# 参考 logseq 中的内容

# %%
from meterviewer.views import quick
from meterviewer import name

# %%
# quick view of dataset
d1 = r"F:\Research\Dataset\MeterData\lens_6\XL\XL\M2L2XL\coor_all_img_np"
quick.quick_view(d1, name.normal_x_y)
# Out:
# Data written to 'F:\Research\Dataset\MeterData\lens_6\XL\XL\M2L2XL\coor_all_img_np\details.toml' successfully.
# (array([[[[ 41,  38,  34],
#           [ 41,  38,  34],
#           [ 41,  38,  34],
#           ...,
#           [ 47,  40,  21],
#           [ 64,  57,  38],
#           [ 86,  79,  60]],
#
#          [[ 41,  38,  34],
#           [ 41,  38,  34],
#           [ 41,  38,  34],
#           ...,
#           [ 48,  41,  22],
#           [ 64,  57,  38],
#           [ 85,  78,  59]],
#
#          [[ 41,  38,  34],
#           [ 41,  38,  34],
#           [ 41,  38,  34],
#           ...,
#           [ 50,  43,  24],
#           [ 64,  57,  38],
#           [ 84,  77,  58]],
#
#          ...,
#
#          [[ 35,  36,  32],
#           [ 35,  36,  32],
#           [ 35,  36,  32],
#           ...,
#           [ 68,  61,  41],
#           [ 69,  62,  42],
#           [ 70,  63,  43]],
#
#          [[ 35,  36,  32],
#           [ 35,  36,  32],
#           [ 35,  36,  32],
# ...

# %%
d2 = r"F:\Research\Dataset\MeterData\lens_6\XL\XL\M2L2XL\Numpy_block_zoom"
_ = quick.quick_view(d2, name.train_x_y)
# Out:
# Data written to 'F:\Research\Dataset\MeterData\lens_6\XL\XL\M2L2XL\Numpy_block_zoom\details.toml' successfully.

# %%
d3 = "F:\Research\Dataset\MeterData\lens_6\XL\XL\neweyem8l5XL\coor_all_img_np"
_ = quick.quick_view(d3, name.train_x_y)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# <>:1: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\svtte\AppData\Local\Temp\ipykernel_29356\228212867.py:1: SyntaxWarning: invalid escape sequence '\R'
#   d3 = "F:\Research\Dataset\MeterData\lens_6\XL\XL\neweyem8l5XL\coor_all_img_np"
# C:\Users\svtte\AppData\Local\Temp\ipykernel_29356\228212867.py:1: SyntaxWarning: invalid escape sequence '\R'
#   d3 = "F:\Research\Dataset\MeterData\lens_6\XL\XL\neweyem8l5XL\coor_all_img_np"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 d3 = "F:\Research\Dataset\MeterData\lens_6\XL\XL\neweyem8l5XL\coor_all_img_np"
# ----> 2 _ = quick.quick_view(d3, name.train_x_y)
#
# File D:\Store\MeterData\meterviewer\src\meterviewer\views\quick.py:14, in quick_view(current_dataset, get_x_y_name, write_config)
#       8 def quick_view(
# ...
